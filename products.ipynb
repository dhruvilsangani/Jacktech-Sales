# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
INVOICE_NO_COL = "Invoice_No."
INVOICE_DATE_COL = "Invoice Date"
STANDARD_RATE_COL = "Standard Rate"
INVOICE_RATE_COL = "Invoice Rate"
QUANTITY_COL = "Invoice Qty"
DISCOUNT_COL = "Disc.Per"
TRANSPORTER_NAME_COL = "TransporterName"
DESTINATION_COL = "Destination"
ITEM_CODE_COL = "Item_code"
AGG_COL = "Amount"
PRODUCT_COL = "SubMainGroup"
GST_COL = "Gst_No"
CUSTOMER_COL = "SupplierName"
columns_of_interest = [
    INVOICE_NO_COL,
    INVOICE_DATE_COL,
    CUSTOMER_COL,
    GST_COL,
    ITEM_CODE_COL,
    PRODUCT_COL,
    QUANTITY_COL,
    STANDARD_RATE_COL,
    INVOICE_RATE_COL,
    DISCOUNT_COL,
    TRANSPORTER_NAME_COL,
    DESTINATION_COL,
    AGG_COL
]

# %%
EXCEL_NAME = "Sales Invoice Register 2020-2026 Mitesh 260508.xlsx"
df = pd.read_excel(EXCEL_NAME, header=0)

# %%
FILE_NAME = "Sales Invoice Register 2014 2020 Mitesh 260509.xlsx"
df_old = pd.read_excel(FILE_NAME, header=0)

# %%
df_old.rename(columns={'Sub Main Group':'SubMainGroup'}, inplace=True)

# %%
df_20_25 = df[columns_of_interest]
df_14_20 = df_old[columns_of_interest]

# %%
df_of_interest = pd.concat([df_14_20, df_20_25], ignore_index=True)
df_of_interest[INVOICE_DATE_COL] = pd.to_datetime(df_of_interest[INVOICE_DATE_COL], errors="coerce")
df_of_interest = df_of_interest.sort_values(INVOICE_DATE_COL, na_position="last").reset_index(drop=True)
df_of_interest.to_excel("df_of_interest.xlsx", index=False)
df_of_interest
# Out:
#        Invoice_No. Invoice Date                SupplierName           Gst_No  \
# 0       SI00000009   2014-04-01     ASIAN TUBE LTD.(UNIT-I)  24AABCA2797E1ZV
# 1       SI00000008   2014-04-01   SIT FLEXIBLE HOSE PVT LTD  24AAKCS2010H1ZS
# 2       SI00000009   2014-04-01     ASIAN TUBE LTD.(UNIT-I)  24AABCA2797E1ZV
# 3       SI00000009   2014-04-01     ASIAN TUBE LTD.(UNIT-I)  24AABCA2797E1ZV
# 4       SI00000009   2014-04-01     ASIAN TUBE LTD.(UNIT-I)  24AABCA2797E1ZV
# ...            ...          ...                         ...              ...
# 523292  SI10001350   2026-05-07   MOHIT INDUSTRIAL PRODUCTS  07CJAPS2649G1Z3
# 523293  SI10001350   2026-05-07   MOHIT INDUSTRIAL PRODUCTS  07CJAPS2649G1Z3
# 523294  SI10001346   2026-05-07       ALFA INDIA ENTERPRISE  19AIAPB3679E1ZF
# 523295  SI10001364   2026-05-07  FLUIDICS ENGINEERS PVT LTD  33AADCF6140J1ZT
# 523296  SI10001364   2026-05-07  FLUIDICS ENGINEERS PVT LTD  33AADCF6140J1ZT
#
#                      Item_code                      SubMainGroup  Invoice Qty  \
# 0                PCH-20-GR2-PP                        PIPE CLAMP         10.0
# 1              H--4WE-10-D-G24   H - SOL. OPE. DIRECTIONAL VALVE          2.0
# 2                    DS-1" BSP                        DOWTY SEAL         10.0
# 3                  DS-1/2" BSP                        DOWTY SEAL         10.0
# 4             HN-1" BSPX1" BSP                        HEX NIPPLE         10.0
# ...                        ...                               ...          ...
# 523292         DRV-12X1/2" BSP                FLOW CONTROL VALVE         12.0
# 523293   2P-3158--C-P-S-S-B2-E                         GEAR PUMP          5.0
# 523294  JT-19--19+13.45--25+25  GEAR COUPLING WITH BORE & KEYWAY         10.0
# 523295                  JTS-28  GEAR COUPLING WITH BORE & KEYWAY          5.0
# 523296  JT-28--28+17.46--40+40  GEAR COUPLING WITH BORE & KEYWAY         10.0
#
#         Standard Rate  Invoice Rate  Disc.Per        TransporterName  \
# 0                 0.0          81.0      30.0
# 1                 0.0        5110.0      27.0
# 2                 0.0          10.0      30.0
# 3                 0.0           7.0      30.0
# 4                 0.0          94.0      30.0
# ...               ...           ...       ...                    ...
# 523292         1270.0        1270.0      40.0             GATI CARGO
# 523293         9100.0        9100.0      30.0             GATI CARGO
# 523294          280.0         280.0      32.0            BNL EXPRESS
# 523295           70.0          70.0      36.0  ORANGE CARGO CARRIERS
# 523296          530.0         530.0      36.0  ORANGE CARGO CARRIERS
#
#        Destination   Amount
# 0              NaN    567.0
# 1              NaN   7460.6
# 2              NaN     70.0
# 3              NaN     49.0
# 4              NaN    658.0
# ...            ...      ...
# 523292  DELHI CITY   9144.0
# 523293  DELHI CITY  31850.0
# 523294     KOLKATA   1904.0
# 523295  COIMBATORE    224.0
# 523296  COIMBATORE   3392.0
#
# [523297 rows x 13 columns]
